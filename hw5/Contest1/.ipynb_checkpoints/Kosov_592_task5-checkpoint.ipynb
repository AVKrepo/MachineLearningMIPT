# %%
import numpy as np
import pandas as pd

from sklearn.linear_model import SGDClassifier
from sklearn.svm import SVC, LinearSVC
from sklearn.linear_model import LogisticRegression

from sklearn.metrics import accuracy_score, roc_auc_score
from sklearn.model_selection import cross_val_score, GridSearchCV, ShuffleSplit
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # Import Data

# %%
data = pd.read_csv('./data/train.csv')
data.drop('id', axis = 1, inplace = True)
X_train = np.asarray(data[data.columns[range(1, data.shape[1])]], dtype = np.double)
y_train = np.asarray(data[['label']], dtype = np.double).ravel()
data.head()
# Out:
#    label  feat1  feat2  feat3  feat4  feat5  feat6  feat7  feat8  feat9  \
# 0      1      7      0      3      0      2      3      0      6      0
# 1      1      0     11      0      0     10      1      0      0      4
# 2      0      9      0      3      0      1      3      0      4      0
# 3      0      0      9      3      2     25      0      4      0      0
# 4      0      0      0      0      0      2      5      0      0      0
#
#     ...     feat207  feat208  feat209  feat210  feat211  feat212  feat213  \
# 0   ...           3        4        2        2        0       13        0
# 1   ...           0        2        0        0        2        8        1
# 2   ...          48       11        2        0        0        4        0
# 3   ...           1       14        1        0        0        0        3
# 4   ...           3       12        0        3        0        4        0
#
#    feat214  feat215  feat216
# 0       11        1        3
# 1       13        0        4
# 2        2        0        0
# 3        0       17        1
# 4       24        4        0
#
# [5 rows x 217 columns]

# %%
data.groupby(['label']).count()
# Out:
#        feat1  feat2  feat3  feat4  feat5  feat6  feat7  feat8  feat9  feat10  \
# label
# 0        327    327    327    327    327    327    327    327    327     327
# 1        573    573    573    573    573    573    573    573    573     573
#
#         ...     feat207  feat208  feat209  feat210  feat211  feat212  feat213  \
# label   ...
# 0       ...         327      327      327      327      327      327      327
# 1       ...         573      573      573      573      573      573      573
#
#        feat214  feat215  feat216
# label
# 0          327      327      327
# 1          573      573      573
#
# [2 rows x 216 columns]

# %% [markdown]
# # Data preprocessing

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_train
# Out:
# array([[ 1.67857588, -0.6426044 ,  0.27134247, ..., -0.09405589,
#         -0.57018666, -0.29529026],
#        [-0.61884494,  1.01109551, -0.70941344, ...,  0.04586196,
#         -0.76376191, -0.16160755],
#        [ 2.33498182, -0.6426044 ,  0.27134247, ..., -0.7236862 ,
#         -0.76376191, -0.6963384 ],
#        ...,
#        [-0.61884494, -0.6426044 , -0.70941344, ...,  0.32569765,
#         -0.76376191,  1.44258501],
#        [-0.61884494, -0.34193169, -0.05557617, ...,  0.11582088,
#         -0.57018666,  0.10575788],
#        [ 1.67857588, -0.6426044 , -0.3824948 , ...,  0.95532796,
#         -0.76376191, -0.29529026]])

# %% [markdown]
# Лучший классификатор: ~0.930,
#
# LogisticRegression(C=0.1, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=500, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=0, solver='saga', tol=0.0001,
#           verbose=0, warm_start=False)

# %% [markdown]
# ### Pipeline

# %%
best_params = {
    'kernel': 'poly', 
    'C': 0.1, 
    'gamma': 1,
}

# %%
clf = Pipeline([
  ('feature_selection', SelectFromModel(LinearSVC(C=1, penalty="l1", dual=False, random_state=0))),
  ('classification', SVC(random_state=0, **best_params))
])

# %%
params = {
    'classification__kernel': ['linear', 'poly', 'rbf', 'sigmoid'],
    'classification__C': [1e-4, 1e-3, 1e-2, 1e-1, 1, 10, 100]
}

# %%
grid_search = GridSearchCV(clf, 
                           params, 
                           scoring='roc_auc', 
                           n_jobs=-2, 
                           cv=5, 
                           verbose=1, 
                           return_train_score=False)
grid_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 28 candidates, totalling 140 fits
# [Parallel(n_jobs=-2)]: Done  36 tasks      | elapsed:    5.2s
# [Parallel(n_jobs=-2)]: Done 140 out of 140 | elapsed:   19.2s finished
# GridSearchCV(cv=5, error_score='raise',
#        estimator=Pipeline(memory=None,
#      steps=[('feature_selection', SelectFromModel(estimator=LinearSVC(C=1, class_weight=None, dual=False, fit_intercept=True,
#      intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#      multi_class='ovr', penalty='l1', random_state=0, tol=0.0001,
#      verbose=0),
#         norm_order=1, prefit=Fals...ly',
#   max_iter=-1, probability=False, random_state=0, shrinking=True,
#   tol=0.001, verbose=False))]),
#        fit_params=None, iid=True, n_jobs=-2,
#        param_grid={'classification__kernel': ['linear', 'poly', 'rbf', 'sigmoid'], 'classification__C': [0.0001, 0.001, 0.01, 0.1, 1, 10, 100]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#        scoring='roc_auc', verbose=1)

# %%
print(grid_search.best_score_)
print(grid_search.best_params_)
grid_search.best_estimator_
# Out:
# 0.966972249040899
# {'classification__C': 0.0001, 'classification__kernel': 'poly'}
# Pipeline(memory=None,
#      steps=[('feature_selection', SelectFromModel(estimator=LinearSVC(C=1, class_weight=None, dual=False, fit_intercept=True,
#      intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#      multi_class='ovr', penalty='l1', random_state=0, tol=0.0001,
#      verbose=0),
#         norm_order=1, prefit=Fals...ly',
#   max_iter=-1, probability=False, random_state=0, shrinking=True,
#   tol=0.001, verbose=False))])

# %%
pd.DataFrame(grid_search.cv_results_)
# Out:
#     mean_fit_time  mean_score_time  mean_test_score param_classification__C  \
# 0        0.708379         0.026415         0.887354                  0.0001
# 1        0.915569         0.021038         0.966972                  0.0001
# 2        0.941885         0.032538         0.871480                  0.0001
# 3        0.946769         0.033252         0.858135                  0.0001
# 4        0.904604         0.021794         0.903488                   0.001
# 5        1.027612         0.019846         0.966972                   0.001
# 6        1.029029         0.036724         0.896839                   0.001
# 7        0.922882         0.032260         0.859250                   0.001
# 8        0.809430         0.015294         0.920945                    0.01
# 9        1.012052         0.020596         0.966972                    0.01
# 10       0.951996         0.037137         0.896839                    0.01
# 11       0.887171         0.030572         0.855623                    0.01
# 12       0.952294         0.013128         0.916335                     0.1
# 13       0.917148         0.019323         0.966972                     0.1
# 14       0.962561         0.037888         0.896483                     0.1
# 15       0.896840         0.020079         0.760646                     0.1
# 16       1.021769         0.009822         0.920521                       1
# 17       0.880690         0.019782         0.966972                       1
# 18       0.980950         0.039147         0.899182                       1
# 19       0.888647         0.016520         0.719225                       1
# 20       0.998300         0.009164         0.914362                      10
# 21       0.918325         0.020050         0.966972                      10
# 22       0.947428         0.032387         0.899182                      10
# 23       0.879901         0.015897         0.727569                      10
# 24       1.020127         0.009010         0.914362                     100
# 25       0.832423         0.019142         0.966972                     100
# 26       1.018060         0.031803         0.899182                     100
# 27       0.603718         0.011741         0.726908                     100
#
#    param_classification__kernel  \
# 0                        linear
# 1                          poly
# 2                           rbf
# 3                       sigmoid
# 4                        linear
# 5                          poly
# 6                           rbf
# 7                       sigmoid
# 8                        linear
# 9                          poly
# 10                          rbf
# 11                      sigmoid
# 12                       linear
# 13                         poly
# 14                          rbf
# 15                      sigmoid
# 16                       linear
# 17                         poly
# 18                          rbf
# 19                      sigmoid
# 20                       linear
# 21                         poly
# 22                          rbf
# 23                      sigmoid
# 24                       linear
# 25                         poly
# 26                          rbf
# 27                      sigmoid
#
#                                                params  rank_test_score  \
# 0   {'classification__C': 0.0001, 'classification_...               20
# 1   {'classification__C': 0.0001, 'classification_...                1
# 2   {'classification__C': 0.0001, 'classification_...               21
# 3   {'classification__C': 0.0001, 'classification_...               23
# 4   {'classification__C': 0.001, 'classification__...               13
# 5   {'classification__C': 0.001, 'classification__...                1
# 6   {'classification__C': 0.001, 'classification__...               17
# 7   {'classification__C': 0.001, 'classification__...               22
# 8   {'classification__C': 0.01, 'classification__k...                8
# 9   {'classification__C': 0.01, 'classification__k...                1
# 10  {'classification__C': 0.01, 'classification__k...               17
# 11  {'classification__C': 0.01, 'classification__k...               24
# 12  {'classification__C': 0.1, 'classification__ke...               10
# 13  {'classification__C': 0.1, 'classification__ke...                1
# 14  {'classification__C': 0.1, 'classification__ke...               19
# 15  {'classification__C': 0.1, 'classification__ke...               25
# 16  {'classification__C': 1, 'classification__kern...                9
# 17  {'classification__C': 1, 'classification__kern...                1
# 18  {'classification__C': 1, 'classification__kern...               16
# 19  {'classification__C': 1, 'classification__kern...               28
# 20  {'classification__C': 10, 'classification__ker...               11
# 21  {'classification__C': 10, 'classification__ker...                1
# 22  {'classification__C': 10, 'classification__ker...               14
# 23  {'classification__C': 10, 'classification__ker...               26
# 24  {'classification__C': 100, 'classification__ke...               11
# 25  {'classification__C': 100, 'classification__ke...                1
# 26  {'classification__C': 100, 'classification__ke...               14
# 27  {'classification__C': 100, 'classification__ke...               27
#
#     split0_test_score  split1_test_score  split2_test_score  \
# 0            0.895257           0.940184           0.909164
# 1            0.963241           0.977997           0.967224
# 2            0.843478           0.889723           0.881739
# 3            0.860079           0.905270           0.884281
# 4            0.915415           0.947036           0.919732
# 5            0.963241           0.977997           0.967224
# 6            0.867391           0.909289           0.900870
# 7            0.863768           0.906324           0.883746
# 8            0.940580           0.945718           0.932977
# 9            0.963241           0.977997           0.967224
# 10           0.867391           0.909289           0.900870
# 11           0.857576           0.904216           0.881472
# 12           0.909223           0.945191           0.926020
# 13           0.963241           0.977997           0.967224
# 14           0.867391           0.905929           0.904682
# 15           0.764427           0.779447           0.786087
# 16           0.884058           0.935705           0.944214
# 17           0.963241           0.977997           0.967224
# 18           0.867391           0.909289           0.909699
# 19           0.741897           0.733597           0.738194
# 20           0.877339           0.926614           0.944214
# 21           0.963241           0.977997           0.967224
# 22           0.867391           0.909289           0.909699
# 23           0.731884           0.737154           0.769498
# 24           0.877339           0.926614           0.944214
# 25           0.963241           0.977997           0.967224
# 26           0.867391           0.909289           0.909699
# 27           0.731884           0.733860           0.767893
#
#     split3_test_score  split4_test_score  std_fit_time  std_score_time  \
# 0            0.853306           0.838057      0.167100        0.002928
# 1            0.953036           0.973279      0.063773        0.001776
# 2            0.853036           0.889474      0.154568        0.002591
# 3            0.827800           0.812551      0.158448        0.002832
# 4            0.865452           0.869096      0.157014        0.001322
# 5            0.953036           0.973279      0.135220        0.001116
# 6            0.899798           0.907018      0.030986        0.002813
# 7            0.827935           0.813765      0.144018        0.000951
# 8            0.890958           0.893927      0.176139        0.001186
# 9            0.953036           0.973279      0.031802        0.001207
# 10           0.899798           0.907018      0.143555        0.000520
# 11           0.820648           0.813495      0.161149        0.001568
# 12           0.906613           0.894332      0.059943        0.000593
# 13           0.953036           0.973279      0.144483        0.001019
# 14           0.897571           0.907018      0.145944        0.001956
# 15           0.767611           0.705263      0.171160        0.001688
# 16           0.914035           0.924696      0.192497        0.000542
# 17           0.953036           0.973279      0.177624        0.002405
# 18           0.902699           0.907018      0.120066        0.001751
# 19           0.707152           0.674764      0.166525        0.001383
# 20           0.908367           0.915385      0.132252        0.000226
# 21           0.953036           0.973279      0.144702        0.001919
# 22           0.902699           0.907018      0.141752        0.001015
# 23           0.698246           0.700675      0.139033        0.000434
# 24           0.908367           0.915385      0.218029        0.000826
# 25           0.953036           0.973279      0.182715        0.001400
# 26           0.902699           0.907018      0.054477        0.002157
# 27           0.698650           0.701889      0.099629        0.002171
#
#     std_test_score
# 0         0.037188
# 1         0.008590
# 2         0.019435
# 3         0.034360
# 4         0.031397
# 5         0.008590
# 6         0.015204
# 7         0.034297
# 8         0.023536
# 9         0.008590
# 10        0.015204
# 11        0.034721
# 12        0.017649
# 13        0.008590
# 14        0.014963
# 15        0.028690
# 16        0.020925
# 17        0.008590
# 18        0.016143
# 19        0.025279
# 20        0.022169
# 21        0.008590
# 22        0.016143
# 23        0.026243
# 24        0.022169
# 25        0.008590
# 26        0.016143
# 27        0.025178

# %% [markdown]
# # Fit final classifier

# %%
estimator = SVC(C=0.0001, cache_size=200, class_weight=None, coef0=0.0,
  decision_function_shape='ovr', degree=3, gamma=1, kernel='poly',
  max_iter=-1, probability=True, random_state=0, shrinking=True,
  tol=0.001, verbose=False)
estimator.fit(X_train, y_train)
# Out:
# SVC(C=0.0001, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=1, kernel='poly',
#   max_iter=-1, probability=True, random_state=0, shrinking=True, tol=0.001,
#   verbose=False)

# %% [markdown]
# # Test data estimation

# %%
test = pd.read_csv('./data/test.csv')
X_test = np.asarray(test[test.columns[range(1, test.shape[1])]])
X_test = scaler.transform(X_test)
# Out:
# /home/avk/study/MIPT/MachineLearning/ml-env/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
X_test
# Out:
# array([[ 0.69396695, -0.34193169, -0.05557617, ..., -0.4438505 ,
#         -0.3766114 , -0.29529026],
#        [ 0.36576398, -0.19159533, -0.70941344, ...,  1.02528689,
#         -0.3766114 , -0.6963384 ],
#        [-0.61884494, -0.6426044 , -0.70941344, ..., -0.51380943,
#         -0.57018666, -0.56265569],
#        ...,
#        [-0.29064197, -0.49226804, -0.70941344, ...,  1.6549172 ,
#         -0.76376191, -0.42897297],
#        [-0.29064197, -0.19159533, -0.05557617, ...,  1.58495827,
#         -0.57018666, -0.6963384 ],
#        [-0.61884494, -0.34193169,  0.27134247, ...,  0.18577981,
#         -0.76376191, -0.6963384 ]])

# %%
# test_predict = estimator.predict(X_test)
test_predict = estimator.predict_proba(X_test)[:, 1]
print(test_predict)
# Out:
# [0.8696696  0.94450525 0.0468955  ... 0.90329626 0.9484737  0.97563392]

# %%
test['label'] = test_predict
test[['id', 'label']].to_csv('submit2.csv', sep=',', index=False)
